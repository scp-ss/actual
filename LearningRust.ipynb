# %% [markdown]
# # Reason For Creation:
# Just saw a couple videos urging me to use notetaking app.
#
# My current method being: Scribbel all info and idea in text.
# <br>
# Write it to ]redacted[.mem. <br>
# And write full story there. <br>
# Then copy the thingy where it is needed. Example 'deref a mut-ref to return a ref' to a .md file.<br>
# Desribe the steps in the redacted.mem file.<br>
# I say redacted cauz its written in a custom langugaeg that is yet to be completed . ill first wait for hte languge to be 100% done then list its nmae yk. <br>
# The redacted file has grown quite large. <br>
# Im planing on creating a custom notetaking fileformat mix of .ipynb and .md, and .excalidraw, but wait for that <br>
